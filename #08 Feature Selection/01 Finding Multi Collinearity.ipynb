# %% [markdown]
# #  Find MultiCollinearity

# %% [markdown]
# ![#01%20Find_Multi%20Collinearity.png](attachment:#01%20Find_Multi%20Collinearity.png)

# %%
# Using OLS

# %% [markdown]
# ![Find_Multi%20Collinearity.png](attachment:Find_Multi%20Collinearity.png)
