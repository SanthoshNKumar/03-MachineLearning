# %% [markdown]
# ![EigenVectors_01_What%20isEigenVector_01.PNG](attachment:EigenVectors_01_What%20isEigenVector_01.PNG)

# %% [markdown]
# ![EigenVectors_01_What%20isEigenVector.PNG](attachment:EigenVectors_01_What%20isEigenVector.PNG)

# %% [markdown]
# ![EigenVectors_04_UseOfEigenVector.PNG](attachment:EigenVectors_04_UseOfEigenVector.PNG)

# %% [markdown]
# ## Understanding Eigen Vectors

# %% [markdown]
# ![EigenVectors_00_UnderstadingEigenVector.PNG](attachment:EigenVectors_00_UnderstadingEigenVector.PNG)

# %% [markdown]
# ## TypesOfLinearTransformation

# %% [markdown]
# ![EigenVectors_05_TypesOfLinearTransformation_01.PNG](attachment:EigenVectors_05_TypesOfLinearTransformation_01.PNG)

# %% [markdown]
# ## MatrixTransformation

# %% [markdown]
# ![EigenVectors_00_MatrixTransformation.PNG](attachment:EigenVectors_00_MatrixTransformation.PNG)

# %% [markdown]
# ![EigenVectors_00_MatrixTransformation_01.PNG](attachment:EigenVectors_00_MatrixTransformation_01.PNG)

# %% [markdown]
# ## Find Eigen Values and Vectors

# %% [markdown]
# ![EigenVectors_02_FindEigenValues.PNG](attachment:EigenVectors_02_FindEigenValues.PNG)

# %% [markdown]
# ![EigenVectors_03_FindEigenVectorFromEigenValue.PNG](attachment:EigenVectors_03_FindEigenVectorFromEigenValue.PNG)

# %% [markdown]
# ![EigenVectors_03_FindEigenVectorFromEigenValue_1.png](attachment:EigenVectors_03_FindEigenVectorFromEigenValue_1.png)
