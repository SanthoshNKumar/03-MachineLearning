# %%
# Importing required libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
# Loading the image 
img = cv2.imread('dog.jpg') #you can use any image you want.
plt.imshow(img,cmap='gray')
plt.show()

# %%
# Splitting the image in R,G,B arrays.
 
blue,green,red = cv2.split(img) 
#it will split the original image into Blue, Green and Red arrays.

# %%
def applyPCA(component):
    #initialize PCA with first 20 principal components
    pca = PCA(int(component))

    #Applying to red channel and then applying inverse transform to transformed array.
    red_transformed = pca.fit_transform(red)
    red_inverted = pca.inverse_transform(red_transformed)

    #Applying to Green channel and then applying inverse transform to transformed array.
    green_transformed = pca.fit_transform(green)
    green_inverted = pca.inverse_transform(green_transformed)

    #Applying to Blue channel and then applying inverse transform to transformed array.
    blue_transformed = pca.fit_transform(blue)
    blue_inverted = pca.inverse_transform(blue_transformed)
    
    return red_inverted,green_inverted,blue_inverted

# %%
red_inverted,green_inverted,blue_inverted = applyPCA(20)

img_compressed = (np.dstack((red_inverted, green_inverted, blue_inverted))).astype(np.uint8)

#viewing the compressed image
plt.imshow(img_compressed)

# With the first 50 Principal components, our output not clear

# %%
red_inverted,green_inverted,blue_inverted = applyPCA(100)

img_compressed = (np.dstack((red_inverted, green_inverted, blue_inverted))).astype(np.uint8)

#viewing the compressed image
plt.imshow(img_compressed)

# With the first 100 Principal components, our output got much clearer.

# %%
red_inverted,green_inverted,blue_inverted = applyPCA(200)

img_compressed = (np.dstack((red_inverted, green_inverted, blue_inverted))).astype(np.uint8)

#viewing the compressed image
plt.imshow(img_compressed)

# With 200 principal components, we were able to create a sharp image just like the original one.
