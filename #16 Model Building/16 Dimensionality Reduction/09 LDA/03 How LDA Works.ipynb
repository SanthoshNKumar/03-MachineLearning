# %%
'''
LDA is mainly used in classification problems where you have a categorical output variable.

# %%
'''

LDA : Linear Discriminant Analysis
    - The aim of LDA is to maximize the separation between two groups or more groups.
    - It is a dimensionality reduction technique that is commonly used for supervised classification problems
    - LDA supports both binary and multi-class classification
    - LDA is mainly used in classification problems where you have a categorical output variable.
    - LDA focuses primarily on projecting the features in higher dimension space to lower dimensions.

# %% [markdown]
# ![LDA%201.png](attachment:LDA%201.png)

# %% [markdown]
# ![LDA%202.png](attachment:LDA%202.png)

# %% [markdown]
# ![LDA%203.png](attachment:LDA%203.png)

# %% [markdown]
# ![LDA%204.png](attachment:LDA%204.png)

# %% [markdown]
# ![LDA%205.png](attachment:LDA%205.png)

# %% [markdown]
# ![LDA%206.png](attachment:LDA%206.png)
