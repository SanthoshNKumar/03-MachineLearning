# %%
'''
List of Deep Leanring Algorithms or architectures
    1.ANN
    2.CNN
    3.RNN
    4.LSTM
    5.GRU
    5.BI-LSTM
    6.GAN
    7.Transformers
    8.Auto Encoders
    9.RBF
    10.Siamese Network

Supervised
    1. ANN
    2. CNN;RNN;LSTM
    
Unsupervised 
    1. Auto Encoders

# %% [markdown]
# ![DL_NNs.png](attachment:DL_NNs.png)

# %%
'''
01 ANN (Artificial Neural Network)
    - ANN is ideal for solving problems regarding data (Tabular data)
    - ANN is also known as a Feed-Forward Neural network because inputs are processed only in the forward direction
    - ANN consists of 3 layers
        1. Input
        2. Hidden 
        3. Output
    - The input layer accepts the inputs, the hidden layer processes the inputs, and the output layer produces the result

# %% [markdown]
# ![ANN.png](attachment:ANN.png)

# %%
'''
02 CNN(ConvNets): 
    - CNNs are commonly used in solving problems related to spatial data, such as images
    - Convolutional Neural Networks (Shift-invariant or Space-invariant ANN),special type of ANN 
    - Convolutional Neural Networks is also known as CNN or ConvNets
    - CNN is one Subject on Computer Vision(CV)
    - CNN always look into the features
    - Convlution Neural networks(ConvNets or CNNs) are category in Neurol networks that have proven very effective in areas 
      such as image recognization and classification.
    - ConvNets have been sucessful identifying faces,objects, and traffic signals apart from powering vision in robots and 
      self driving cars
    - In CNN for each filters there will be one bias. if Conv block has 10 features then 10 bias will added

# %% [markdown]
# ![cnn.png](attachment:cnn.png)

# %%
'''
03 RNN
    - RNNs are better suited to analyzing temporal, sequential data, such as text or videos
    - Type of Neural network where,the output from previous step are fed as input to the current step.
    - In traditional neural networks, all the inputs and outputs are independent of each other, but in RNN we deal witj the 
      caseslike when it is required to predict the next word of a sentence, the previous words are required and hence there 
      is a need to remember the previous words.

# %% [markdown]
# ![rnn.png](attachment:rnn.png)

# %%
'''
04 LSTM : Long-Short-Trem-Memory: 
    - Special kind of RNN it is capable of learning long term dependecies,remembering information for long periods as default 
      behaviour.
    - LSTM has three gates (input, output and forget gate)

# %% [markdown]
# ![lstm.png](attachment:lstm.png)

# %%
'''
GRU : Gated Recurrent Unit
    - GRUs are improved version of standard recurrent neural network
    - To solve the vanishing gradient problem of a standard RNN, GRU uses, so-called, 'update gate' and 'reset gate'. 
    -

# %% [markdown]
# ![gru.png](attachment:gru.png)

# %%
'''
Comparion between LSTM and GRU

1. LSTM has Three gates (Input, Output, and Forget)
   GRU has to gates (update gate and reset gate)
   
2. LSTM has memory unit
   GRU unit does not have to use a memory unit to control the flow of information
   
3. LSTM may needs lareg data to generalize the model
   GRUs have fewer parameters and thus may train a bit faster or need less data to generalize.

# %%
'''
05 Bi-LSTM : Bidirectional LSTM
    -

# %% [markdown]
# ![bilstm.png](attachment:bilstm.png)

# %%
'''
06 GAN : Generative Adversarial Networks

# %% [markdown]
# ![gan.png](attachment:gan.png)

# %%
'''
07 Transformers
    - The name 「Transformer」in field of Natural Language Processing(NLP) is defined by a paper published by
      Google named “Attention is all you need” in Mid 2017.
    - In short, the concept of Transformer is about replacing Recursive or Convolutional Neuron Layer by Self-Attention Layer.
    - Transformers have changed the application of Machine Learning in Natural Language Processing. 
      They have replaced LSTMs as state-of-the-art (SOTA)

    - Transformer architecture implements an encoder-decoder structure
    - Self-Attention: The Transformer encoder
    - Transformers were developed to solve the problem of sequence transduction, or neural machine translation.
    - That means any task that transforms an input sequence to an output sequence. 
      This includes speech recognition, text-to-speech transformation, etc


Why Transformers
    - There were some issue with RNN and LSTM
    
What is the problem with RNN and LSTM
    - When sentences are too long LSTMs still don’t do too well. 
      The reason for that is that the probability of keeping the context from a word that is far away from the current word 
      being processed decreases exponentially with the distance from it.
      
      That means that when sentences are long, the model often forgets the content of distant positions in the sequence. 
      Another problem with RNNs, and LSTMs, is that it’s hard to parallelize the work for processing sentences, since you are 
      have to process word by word. 
      
Attention:

To solve some of these(issues with RNN and LSTM) problems, researchers created a technique for paying attention to specific 
words.

# %% [markdown]
# ![tranformers.JPG](attachment:tranformers.JPG)

# %%
'''
08 Autoencoder
    - unsupervised learning technique
    - An autoencoder is, by definition, a technique to encode something automatically.
    - By using a neural network, the autoencoder is able to learn how to decompose data (in our case, images) into fairly 
      small bits of data, and then using that representation, reconstruct the original data as closely as it can to the 
      original.
    - Autoencoders are a very useful dimensionality reduction technique.
    - Autoencoders are a specific type of feedforward neural networks where the input is the same as the output
    - They compress the input into a lower-dimensional code and then reconstruct the output from this representation.
    - An autoencoder consists of 3 components: encoder, code and decoder. 
    - The encoder compresses the input and produces the code, the decoder then reconstructs the input only using this code.
    - Autoencoders are mainly a dimensionality reduction (or compression) algorithm with a couple of important properties.

# %% [markdown]
# ![autoencoder.png](attachment:autoencoder.png)

# %%
'''
Sparse Autoencoder

# %%
'''
Stacked Autoencoder
    - A stacked autoencoder is a neural network consist several layers of sparse autoencoders where output of each hidden 
      layer is connected to the input of the successive hidden layer

# %% [markdown]
# ![stacked%20auto%20encoder.png](attachment:stacked%20auto%20encoder.png)

# %%
'''
09 RBF : Radial Basis Networks
    - Radial basis networks are an uncommon subtype of neural network that uses radial basis functions as the 
      activation function (instead of the logistic function or ReLU or other linear or nonlinear peers)
    - RBNs can be used for functional approximation.

# %% [markdown]
# ![rbf.png](attachment:rbf.png)

# %%
'''
10 Siamese Network

# %% [markdown]
# ![Siamese%20Network.png](attachment:Siamese%20Network.png)

# %%
The GPT-2 is built using transformer decoder blocks. BERT, on the other hand, uses transformer encoder blocks.
The GPT2, and some later models like TransformerXL and XLNet are auto-regressive in nature. BERT is not.
