# %%
'''
Machine Learning

# %%
'''
List of Machine Learning Algorithms
    
    - Supervised Algorithm
        1. Linear Regression (Regression)
            - Linear Regression
            - Polynominal Regression
            - Ridge Regreesion
            - Lassco Regression
            - LAR(Least Angle Regression)
            - Robust Regression
                - HuberRegressor
                - RANSACRegressor
                - TheilSenRegressor
            - Isotonic Regression
            - Exponential Regression
            - Sinusoidal_Regression
            - Linear Regression for Cutsom Function
            
        2. Logistic Regression (Classification)
        3. Decision Tree (Regression/ Classification)
        4. Naïve Bayes(Classification)
        5. Support Vector Machine-SVM (Regression/ Classification)
        6. Random Forest (Regression / Classification)
        7. K Nearest Neighbours(Regression / Classification)
        8. Ensemble Learning
            - Simple Ensemble Techniques
                - Voting (Regression / Classification)
                - Averaging
                - Weighted Averaging
            - Stacking (Regression / Classification)
            - Blending
            - Bagging
                1. Bagging Classifier
                2. Random Forest (Regression / Classification)
                3. ExtraTree (Regression / Classification)
                
            - Boosting
                1. AdaBoost (Regression / Classification)
                3. Gradient Boosting (Regression / Classification)
                4. XG Boost(Extreme Gradient Boosting)
                5. Light GBM
                6. CatBoost
                7. IsolationForest
        
    - Semi-supervised learning
        - Speech Analysis
        - Web Content Classification
        - Text Classification
    
    - Unsupervised Algorithm
        1. Clustering
            - K Means Clustering
            - MiniBatchKMeans
            - Hierarchical or Agglomerative Clustering
            - SpectralClustering
            - t-SNE
            
        2. Dimension Reduction
            - Principal Component Analysis (PCA)
            - SparsePCA
            - Factor Analysis
            - SVD (Singular Value Decomposition)
            - Truncated SVD
            - Kernel PCA for Non Linear Dimensionality Reduction
            - IncrementalPCA
            - Linear discriminant analysis (LDA)
            - Dictionary learning
            - Manifolds t-SNE
            - Non-negative matrix factorization (NMF)
        
    - Reinforcement Learning
        - Artificial Neural Networks(ANN)
        - Recommendation System

# %%
'''
List of Deep Learning Algorithm

    1. ANN or Multilayer Perceptrons (MLPs)
    2. Convolutional Neural Networks (CNNs)
    3. Recurrent Neural Networks (RNNs)
    4. Long Short Term Memory Networks (LSTMs)
    5. Generative Adversarial Networks (GANs)
    6. Autoencoders
    7. Radial Basis Function Networks (RBFNs)
    8. Self Organizing Maps (SOMs) 
    9. Deep Belief Networks (DBNs)

# %%
'''
List of Computer Vision Algorithm or Models
    1. Image Classification
        - LeNet
        - AlexNet
        - ZfNet
        - VGG
        - Inception
        - ResNet
        - DenseNet
        - SqeezeNet
        - Efficeient Net
        - NASNET
    
    2. Object Detection
        - Region-based Convolutional Neural Networks (R-CNN)
        - Region-based Fully Convolutional Network (R-FCN)
        - Fast R-CNN.
        - Faster R-CNN.
        - Histogram of Oriented Gradients (HOG)
        - Single Shot Detector (SSD)
        - Spatial Pyramid Pooling (SPP-net)
        - YOLO (You Only Look Once)
        
    3. Image Segmentation
        - MaskRCNN
