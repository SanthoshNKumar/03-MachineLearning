# %%
'''
The validation curve is a graphical technique that can be used to measure the influence of a single hyperparameter. 
By looking at this curve, you can determine if the model is underfitting, overfitting or just-right for some range of 
hyperparameter values

'''

# %%
'''
Difference between Leanring and validation Curve
    - Both curves show the training and validation scores of an estimator on the y-axis
    
    - A learning curve plots the score over varying numbers of training samples
    - A validation curve plots the score over a varying hyper parameter.
    
    - The learning curve is a tool for finding out if an estimator would benefit from more data, or if the model is too 
      simple (biased)
    - The validation curve is a tool for finding good hyper parameter settings

# %% [markdown]
# ![learning%20and%20validation.png](attachment:learning%20and%20validation.png)
