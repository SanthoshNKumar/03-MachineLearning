# %%
'''

# What is Gradent Descent?
    - Gradient descent is a first-order iterative optimization algorithm for finding a local minimum of a differentiable 
      function.

# %% [markdown]
# ### 01 Batch Gradient Descent:

# %%
'''
- Weights are updated after computing the gradient of error with respect to the entire training set

Issues :
    - It consider complete or whole datset while computing the weights. so it is slow
    - Does't allow update model online
    - Memory and computation Issue  if dataset is huge
    
 Weight Updates:

    theta0 = theta0 - (learningrate * dtheta0)
    theta1 = theta1 - (learningrate * dtheta1)

'''

# %% [markdown]
# ![SGD_01.JPG](attachment:SGD_01.JPG)

# %% [markdown]
# ### 02 Stochastic Gradient Descent :

# %%
'''
- Weights are updated after computing the gradient of error with respect to a single training

# %% [markdown]
# ![SGD.JPG](attachment:SGD.JPG)

# %% [markdown]
# ### 03 Mini Batch Gradient Descent:

# %%
'''
- Weights are updated after computing the gradient of error with respect to a subset( n Samples) of the training set.
                                                         
'''

# %% [markdown]
# ![Mini%20SGD.JPG](attachment:Mini%20SGD.JPG)

# %%
# Oscillations in Gradient Descent

# %% [markdown]
# ![Osscilation.png](attachment:Osscilation.png)

# %% [markdown]
# ![Osscilation_01.png](attachment:Osscilation_01.png)
