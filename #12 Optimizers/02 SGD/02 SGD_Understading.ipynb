# %%
import tensorflow as tf

tf.enable_eager_execution()

# %%
import numpy as np
from numpy import random
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

X = [30, 35, 37, 59, 70, 76, 88, 100]
Y = [1100, 1423, 1377, 1800, 2304, 2588, 3495, 4839]

X = np.reshape(X,(-1,1))
Y = np.reshape(Y,(-1,1))

scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
M = tf.Variable(5.0) 
C = tf.Variable(0.0) 

loss = []
iteration = []

opt = tf.keras.optimizers.SGD(learning_rate=0.01,clipnorm=1.0)

for epoch in range(1000):
    iteration.append(epoch)
    
    opt.minimize(lambda : sum(abs(Y - M*X - C)), var_list=[M, C])
    # print(sum((y - M*x - C)**2).numpy())
    loss.append(sum((Y - M*X - C)**2).numpy())
    print(M.numpy())
    print(C.numpy())
# Out:
# WARNING:tensorflow:From c:\users\insakum46\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:172: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 5.01
# 0.01
# 5.0200005
# 0.02
# 5.0300007
# 0.03
# 5.040001
# 0.04
# 5.050001
# 0.049999997
# 5.0600014
# 0.059999995
# 5.0700016
# 0.06999999
# 5.080002
# 0.07999999
# 5.090002
# 0.08999999
# 5.1000023
# 0.09999999
# 5.1100025
# 0.109999985
# 5.1200027
# 0.11999998
# 5.130003
# 0.12999998
# 5.140003
# 0.13999999
# 5.1500034
# 0.14999999
# 5.1600037
# 0.16
# 5.170004
# 0.17
# 5.180004
# 0.18
# 5.1900043
# 0.19000001
# 5.2000046
# 0.20000002
# 5.210005
# 0.21000002
# 5.220005
# 0.22000003
# 5.2300053
# 0.23000003
# 5.2400055
# 0.24000004
# 5.2500057
# 0.25000003
# 5.260006
# 0.26000002
# 5.270006
# 0.27
# 5.2800064
# 0.28
# 5.2900066
# 0.29
# ...

# %%
from numpy import array
from numpy.linalg import norm
a = array([1, 2, 3])
print(a)
l1 = norm(a, 1)
print(l1)
# Out:
# [1 2 3]
# 6.0
