# %% [markdown]
# ### Deploy ML Model on AWS EC2

# %%
'''
Steps :

    1. Build Flask Application
    2. Run and Check in the Local
    3. Create AWS Account (Free Tier)
    4. Create EC2 Instance (Ubuntu)
    5. Create Putty and Putty gen
    6. Generate Private Key with putty gen
    7. Download WinSCP
    8. Update the port in Flask Code
    9. Install the Libraries by Connecting through Putty
    10. Run Python app.py

# %%
'''
Putty gen : 
   - It is a free and open-source terminal emulator, serial console, and network file transfer application. 
     It supports several network protocols, including SCP, SSH, Telnet, rlogin, and raw socket connection. 
     It can also connect to a serial port.

# %%
'''

WinSCP: 
    - It is a free and open-source SFTP, FTP, WebDAV, Amazon S3, and SCP client for Microsoft Windows. 
      Its main function is secure file transfer between a local and a remote computer.

# %%
'''
Step 1: Create Flask application along with ML Model endpoint

# %%
'''
Step 2: Download and Install Putty and WinSCP on the Local Machine: 
        The Required Software’s which helps in connecting the local machine with the             
        AWS EC2 instance

# %%
'''
Step 3: Go to AWS Management Console Search for EC2 in AWS Cloud

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
'''
Step 4: Creating an AWS EC2 Instance
    1. Choose an Amazon Machine Image (AMI)
    2. Choose Instance Type
    3. Edit Security Groups
    4. Allow HTTP (Port 80), SSH (Port 22), HTTPS (Port 443) inbound traffic and press next
    5. Creating a Private Key Pair

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %%
'''
Step 5: Converting private key from PPM to PPK Format using PuttyGen
    - Click on load and add the PPM file you recently downloaded
    - Click on “Save private key” and store it.

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %%
'''
Step 6: Transferring Project files using WinSCP (Local to EC2 Instance)
    - Copy the Public DNS from the EC2 Instance
    - Open the WinSCP and need to paste this DNS address in the host input value

# %% [markdown]
# ![7.PNG](attachment:7.PNG)

# %%
'''
    -  Click on advanced options and go to “Authentication” and insert the created private key in PPK format. 
       The window looks similar to below shown one.

# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %%
'''

    Now click on OK and go to log in. 
    Now you can be able to connect with the ubuntu server.

# %% [markdown]
# ![9.PNG](attachment:9.PNG)

# %%
'''
    - Now select the project files you wanted to add to the server and drag and drop to the right-side section in the window. 
    - The file transfer starts and after a while files will be transferred. 
    - The window looks similar to below shown one.

# %%
'''
Step 6 : Connect to the Instance using Git Bash

# %% [markdown]
# ![10.PNG](attachment:10.PNG)

# %%
'''
Step 7 : Install the Required Libraries and run the Flask Application.

# %% [markdown]
# ![11.PNG](attachment:11.PNG)

# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ![13.PNG](attachment:13.PNG)
