# %% [markdown]
# ##                           Model Deployment on Android using Tensorflow

# %%
'''
TF Lite: 
 - TensorFlow Lite is a platform developed by Google to train Machine Learning models on mobile, IoT (Interned of Things) 
   and embedded devices.

# %%
'''

Step 1: Creating and training a Machine Learning model in Python using TensorFlow or Keras

Firstly, we are going to create a Linear Regression model and train it with the predefined data

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
'''
Step 2: Converting our model in a suitable format for TensorFlow Lite using TensorFlow Lite converter.

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %%
'''
Step 3: Deploying our Machine Learning model on our mobile device using TensorFlow Lite interpreter.

# %%
'''
3.1 : Create an Android App using TensorFlow Lite to use the Machine Learning model of Linear Regression in Android

# %%
'''
3.2 : add .tflite model into our Android app

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %%
'''
3.3: Open your build.gradle file and add dependency there

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %%
'''
3.4. Add these lines after BuildType:

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %%
'''
3.5 And now you can sync the Gradel to install required TensorFlow files.
    - MainActivity.java
    
Import the TensorFlow Interpreter.

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %%
'''
3.6 Define the Interpreter as tflite

# %% [markdown]
# ![7.PNG](attachment:7.PNG)

# %%
'''
3.7 Now we have to load the files from the assets folder for that we call the loadModelFile.

# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %%
'''
3.8 To load the assets folder file, we have to use MappedByteBuffer.

# %% [markdown]
# ![9.PNG](attachment:9.PNG)

# %%
'''
3.9 We have one EditText in the app with variable name et, we will read the value and pass to get the prediction

# %% [markdown]
# ![10.PNG](attachment:10.PNG)

# %%
'''
3.10 doInference() function has one input array which is a 1D array and ouput will be of the 2D array, so we initialize 
     them and then tflite.run(input, output), we will save the output value and return it to prediction.

# %% [markdown]
# ![11.PNG](attachment:11.PNG)

# %%
'''
3.11 Lastly, we have TextView named hw, we will write the prediction to the TextView.

# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %%
'''
Step 4: Optimizing the model memory consumption and accuracy.
