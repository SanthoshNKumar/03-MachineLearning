# %%
'''

1.Create below the files in the Spyder
-App.py
-Procfile
-requirements.txt

app.py

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
'''

Procfile is a mechanism for declaring what commands are run by your application's dynos on the Heroku platform.
The Heroku Platform uses the container model to run and scale all Heroku apps. The containers used at Heroku are called “dynos.”

# %%
'''

Procfile

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
'''

To specify Python package dependencies on Heroku via pip, add a pip requirements file named requirements.txt to the root of 
your repository.

# %%
'''
requirements.txt

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
'''

Push above the files into the GitHub Repository
    1.Create New Repository 
    2.Upload the files

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
'''
2. Create and Login Heroku

# %% [markdown]
# ![5.png](attachment:5.png)

# %%
'''
3.Create Webapp in Heroku

# %% [markdown]
# ![6.png](attachment:6.png)
#
# /n
#
# ![7.png](attachment:7.png)

# %%
'''
4.falsktutorial is webapp in the Heroku

# %% [markdown]
# ![8.png](attachment:8.png)

# %%
'''
Here we are choosing Deployment method as GitHub 

Different Deployment Method

# %% [markdown]
# ![9.png](attachment:9.png)

# %%
'''
5. Download and Install Heroku CLI

# %%
'''
6. Commands to be installed for Heroku Deployment

# %%
'''
Open the command Prompt

Open the command Prompt

Heroku Login -I
Login using Username and Password

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
'''
Create Virtual Environment

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
'''
Install Flask and Run Activate

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
'''
Install gunicorn

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
'''
Initialize git

# %% [markdown]
# ![5.png](attachment:5.png)

# %%
'''
Connect to Heroku git and application

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %%
'''
Add files

# %% [markdown]
# ![7.PNG](attachment:7.PNG)

# %%
'''
Commit changes

# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %%
'''
Push the changes

# %% [markdown]
# ![9.PNG](attachment:9.PNG)

# %%
'''
** Create requirements.txt file

# %% [markdown]
# ![10.PNG](attachment:10.PNG)
