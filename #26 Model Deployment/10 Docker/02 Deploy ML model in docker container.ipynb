# %%
'''
1.Build and train the model.
2.Create an API of the model. (Here we have put it in a flask API).
3.Create the requirements.txt file containing all the required libraries.
4.Create the docker file with necessary environment setup and start-up operations.

# %% [markdown]
# ![11.png](attachment:11.png)

# %%
'''
5.Build the docker image.

# %%
'''
*** We can host this docker container on the Docker Hub also we Deploy same on AWS EC2  and Azure VMs
*** Separate doc created for referring how to deploy docker container on Azure VMS
